# %%
import IPython.display

from ColoredRabinGames import *

# %%
def display_compute_display(game):
    IPython.display.display(game)
    game.compute_green_sets()
    IPython.display.display("After green sets computation", game)

# %% [markdown]
# ## Counterexamples

# %% [markdown]
# Counterexample for only green sets and iterative algorithm

# %%
ce1 = GameColored(filename='ce1.game')
display_compute_display(ce1)
# Out:
# (1):
#   green sets: {g1}
#   successors: ['2']
# (3):
#   green sets: {g2}
#   successors: ['4']
# [2]:
#   red sets: {r1}
#   successors: ['3']
# [4]:
#   red sets: {r2}
#   successors: ['1']
# 'After green sets computation'
# (1):
#   green sets: {g1}
#   successors: ['2']
#   S(1) = {{g1},{g2}}
# (3):
#   green sets: {g2}
#   successors: ['4']
#   S(3) = {{g1},{g2}}
# [2]:
#   red sets: {r1}
#   successors: ['3']
#   S(2) = {{g2}}
# [4]:
#   red sets: {r2}
#   successors: ['1']
#   S(4) = {{g1}}

# %% [markdown]
# The set of green sets S is nonempty for every node. But ENV wins everywhere.

# %% [markdown]
# ### Green sets & red sets:cost

# %%
game = GameColored(filename='ce_green_and_red.game')
display_compute_display(game)
# Out:
# (1):
#   green sets: {g1}
#   successors: ['4', '5']
# (2):
#   green sets: {g2}
#   successors: ['4', '5']
# [4]:
#   red sets: {r1}
#   successors: ['7', '8']
# [5]:
#   red sets: {r2}
#   successors: ['7', '8']
# (7):
#   green sets: {g3}
#   successors: ['10', '11']
# (8):
#   green sets: {g4}
#   successors: ['10', '11']
# [10]:
#   red sets: {r3}
#   successors: ['12']
# [11]:
#   red sets: {r4}
#   successors: ['12']
# [12]:
#   successors: ['1', '2']
# 'After green sets computation'
# (1):
#   green sets: {g1}
#   successors: ['4', '5']
#   S(1) = {{g1},{g3,g4}}
# (2):
#   green sets: {g2}
#   successors: ['4', '5']
#   S(2) = {{g2},{g3,g4}}
# [4]:
#   red sets: {r1}
#   successors: ['7', '8']
#   S(4) = {{g3,g4}}
# [5]:
#   red sets: {r2}
#   successors: ['7', '8']
#   S(5) = {{g3,g4}}
# (7):
#   green sets: {g3}
#   successors: ['10', '11']
#   S(7) = {{g1,g2},{g3}}
# (8):
#   green sets: {g4}
#   successors: ['10', '11']
#   S(8) = {{g1,g2},{g4}}
# [10]:
#   red sets: {r3}
#   successors: ['12']
#   S(10) = {{g1,g2}}
# [11]:
#   red sets: {r4}
#   successors: ['12']
#   S(11) = {{g1,g2}}
# [12]:
#   successors: ['1', '2']
#   S(12) = {{g1,g2},{g3,g4}}

# %% [markdown]
# Extension of game1. It shows that we can not forget information that SYS has to play one of two red sets.
#
# TODO: Enhance the description
